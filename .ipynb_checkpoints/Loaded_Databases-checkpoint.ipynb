# %%
from datetime import timedelta
import datetime as dt
from pandas.tseries.offsets import BDay
import os
import pandas as pd
import csv
import matplotlib.pyplot as plt
from ipywidgets import widgets as wg
from ipywidgets import interactive
from IPython.display import display
from itertools import izip
from pandas import *
cmap = plt.get_cmap('viridis')
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)

sector_info = pd.read_csv('databases/securities.csv')
sector_info = sector_info[['Ticker symbol','Security','GICS Sector', 'GICS Sub Industry']]


# entire_stock_analyst_hist_df = pd.read_csv('entire_ticker_analyst_history')
# snp_500_analyst_history_df = pd.read_csv('snp500analyst_history')
# snp_500_stock_history_df = pd.read_csv('snp500stockHistories')
snp_500_merged_data = pd.read_csv('databases/snp500merged',index_col=0)

#uppercase the firms to fix uniformity mistakes
snp_500_merged_data['firm'] = snp_500_merged_data['firm'].str.upper()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = snp_500_merged_data.copy()

# %% [markdown]
# ### Chart Each Ticker

# %% [markdown]
# #### Instructions
#
# * 1)Load the imports and databases
# * 2)Run the code under this cell
# * 3)Type in the symbol into the box and press enter
# * 4)Run next cell and select the Institution that you would like to perform analysis (no need to press enter)
# * 5)Run the following Cell

# %%
def firm_tofromGradeStats(df1):
    lst = []
    for firm in df1.firm.unique().tolist():
        lst1 = []
        lst3 = []
        lst6 = []
        lst9 = []
        lstn = []
        df2 = df1.loc[df1['firm'] == firm]
        unique_grades = df2['toGrade_combined'].unique().tolist()
        cleaned_grades = [x for x in unique_grades if str(x)!= 'nan']
        df3 = pd.DataFrame({'toGrade':cleaned_grades})
        for grade in df3['toGrade'].values:
        
            dayaftersM = df2.loc[df2['toGrade_combined'] == grade]['percent1After'].mean()
            days30M = df2.loc[df2['toGrade_combined'] == grade]['percent30'].mean()
            days60M = df2.loc[df2['toGrade_combined'] == grade]['percent60'].mean()
            days90M = df2.loc[df2['toGrade_combined'] == grade]['percent90'].mean()
            n = len(df2.loc[df2['toGrade_combined'] == grade])
            lst1.append(dayaftersM)
            lst3.append(days30M)
            lst6.append(days60M)
            lst9.append(days90M)
            lstn.append(n)
            
        df3['firm'] = firm
        df3['dayAfterM'] = pd.Series(lst1)
        df3['days30M'] = pd.Series(lst3)
        df3['days60M'] = pd.Series(lst6)
        df3['days90M'] = pd.Series(lst9)
        df3['n'] = pd.Series(lstn)
        
        lst.append(df3)
    concatlist = pd.concat(lst)
    
    return concatlist

def enter_ticker(df):
    ticker = raw_input('Please enter a stock ticker').upper()
    ticker_df = df.loc[df['stockTicker'] == ticker]
    return ticker_df


ticker_data = enter_ticker(snp_500_merged_data)

to_analyst_value_count = ticker_data.firm.value_counts().to_frame().index.values.tolist()

analyst_data = wg.Dropdown(
        options = to_analyst_value_count,
        description = 'Analyst Firm:'  
    )


colors = {'Strong_Buy':'g',
          'Buy':'b',
          'Hold': 'y',
          'Sell':'r',
          'Underperform':'p'}
    
def plot_ticker(df,analyst_data):

    analyst_data_for_ticker_df = df.loc[df['firm'] == analyst_data.value]
    pylab.rcParams['figure.figsize'] = (10,6)
    plt.plot_date(df['Date'],df['Open'],linestyle='solid',marker='None')
    for xc in analyst_data_for_ticker_df.Date:
        c = analyst_data_for_ticker_df.loc[analyst_data_for_ticker_df['Date']==xc].toGrade_combined.iloc[0]
        plt.axvline(x=xc,color=colors[c])
# Out:
# Please enter a stock tickermmm

# %%
stock_analyst_statsdf = firm_tofromGradeStats(df)

# %%
analyst_data

# %% [markdown]
# ### Chart Description
#
# * The chart is the tickers stock history, the lines provided are the dates the specific stock analyst graded that specific stock color coded with: Buy=Blue, Strong Buy=Green, Hold=Yellow, Sell=Red, Underperform=Purple

# %%
company_list_for_analyst = df.loc[df['firm'] == analyst_data.value]
unique_tick = company_list_for_analyst.stockTicker.unique().tolist()
company_list_for_analystdf = pd.DataFrame({'stockTicker':unique_tick})
n=[]
for tick in unique_tick:
    n.append(len(company_list_for_analyst.loc[company_list_for_analyst['stockTicker']==tick]))
company_list_for_analystdf['n_instances'] = pd.Series(n)  
company_list_for_analystdf = company_list_for_analystdf.sort_values('n_instances',ascending = False)
company_list_for_analystdf = pd.merge(company_list_for_analystdf,sector_info,how='left',left_on=['stockTicker'],right_on=['Ticker symbol']).drop('Ticker symbol',1)
company_list_for_analystdf['firm'] = analyst_data.value

print "Colors :"
print colors
plot_ticker(ticker_data,analyst_data)
# Out:
# Colors :
# {'Sell': 'r', 'Underperform': 'p', 'Strong_Buy': 'g', 'Buy': 'b', 'Hold': 'y'}

# %% [markdown]
# * Next cell shows the n_instances that that specific analyst firm has done each of the 5 different grades; and the total means of the percentages 1,30,60, and 90 days after open

# %%
stock_analyst_statsdf.loc[stock_analyst_statsdf['firm'] == analyst_data.value]
# Out:
#       toGrade           firm  dayAfterM   days30M   days60M   days90M       n
# 0        Hold  DEUTSCHE BANK   0.031118  1.310143  2.463270  3.963574  1753.0
# 1         Buy  DEUTSCHE BANK   0.192338  1.412155  2.486420  3.901490  1926.0
# 2  Strong_buy  DEUTSCHE BANK   1.025868  0.000211 -0.806287  2.523425     3.0
# 3        Sell  DEUTSCHE BANK  -0.213118 -2.256385 -0.334895 -0.503526    68.0

# %% [markdown]
# * Next cell shows the instances where the lines on the graph occur for the stock ticker selected

# %%
ticker_data.loc[ticker_data['firm'] == analyst_data.value][['stockTicker', 'Date', 'Open', 'firm','fromGrade_combined','toGrade_combined','percent1Before','percent1After','percent30','percent60','percent90']]
# Out:
#      stockTicker        Date        Open           firm fromGrade_combined  \
# 0            MMM  2012-02-09   87.540001  DEUTSCHE BANK                NaN
# 1437         MMM  2012-10-24   89.029999  DEUTSCHE BANK                NaN
# 1439         MMM  2012-12-13   92.949997  DEUTSCHE BANK                NaN
# 1443         MMM  2013-01-25   99.790001  DEUTSCHE BANK                NaN
# 1453         MMM  2013-08-05  118.169998  DEUTSCHE BANK                NaN
# 1466         MMM  2014-04-25  136.500000  DEUTSCHE BANK                NaN
# 1468         MMM  2014-07-25  145.660004  DEUTSCHE BANK                NaN
# 1486         MMM  2015-06-24  159.679993  DEUTSCHE BANK                NaN
# 1492         MMM  2016-01-28  146.160004  DEUTSCHE BANK                NaN
#
#      toGrade_combined  percent1Before  percent1After  percent30  percent60  \
# 0                Hold             NaN      -0.388398  -0.502631  -2.490290
# 1437             Hold        0.718858      -0.516679   0.292039        NaN
# 1439             Hold        0.828407      -1.022052   3.711678  10.844543
# 1443             Hold       -0.410867       1.192506   2.324882   5.892371
# 1453             Hold       -0.160781      -0.296182  -4.307351   0.169252
# 1466             Hold       -0.087908       0.681314   3.663004   5.311355
# 1468             Hold       -0.102986      -0.508037  -0.453113  -0.858163
# 1486             Hold        0.457171      -1.146034  -6.776047 -11.159815
# 1492             Hold       -0.827865       1.423099   8.107547  13.143124
#
#       percent90
# 0     -1.222298
# 1437  11.625293
# 1439  13.932227
# 1443   4.128673
# 1453   6.414489
# 1466   6.168497
# 1468   1.668263
# 1486 -14.435113
# 1492  14.244658

# %% [markdown]
# * Next cell shows the stockTickers the specific analysts firm invests in, sorted by decending order of the n_instances of the count that the analyst firm graded individual tickers, as well as the ticker's sector

# %%
company_list_for_analystdf
# Out:
#     stockTicker  n_instances                            Security  \
# 0           STT           29                  State Street Corp.
# 1          NTRS           28                Northern Trust Corp.
# 2            BK           27   The Bank of New York Mellon Corp.
# 3          SCHW           27          Charles Schwab Corporation
# 4          ETFC           26                             E*Trade
# 5           BEN           24                  Franklin Resources
# 6          CBOE           22                                 NaN
# 7           CHK           22                   Chesapeake Energy
# 8           CXO           22                    Concho Resources
# 9           BLK           22                           BlackRock
# 10           FE           21                    FirstEnergy Corp
# 11          AMG           21       Affiliated Managers Group Inc
# 12          FDX           21                   FedEx Corporation
# 13          EXC           21                        Exelon Corp.
# 14          CNC           20                 Centene Corporation
# 15          XEC           20                      Cimarex Energy
# 16         WYNN           20                    Wynn Resorts Ltd
# 17         TROW           20                 T. Rowe Price Group
# 18          ALL           20                       Allstate Corp
# 19          UNP           19                       Union Pacific
# 20          AIG           19  American International Group, Inc.
# 21          NSC           19              Norfolk Southern Corp.
# 22          IVZ           19                        Invesco Ltd.
# 23          AET           19                           Aetna Inc
# 24          NEM           19    Newmont Mining Corp. (Hldg. Co.)
# 25          NEE           19                      NextEra Energy
# 26          PEG           19        Public Serv. Enterprise Inc.
# 27         PCLN           18                   Priceline.com Inc
# 28          ICE           18           Intercontinental Exchange
# 29           CI           18                         CIGNA Corp.
# ..          ...          ...                                 ...
# 388         IRM            2          Iron Mountain Incorporated
# 389         UAA            2                        Under Armour
# 390         URI            2                United Rentals, Inc.
# 391         PSA            2                      Public Storage
# 392         KHC            2                      Kraft Heinz Co
# 393         HBI            1                     Hanesbrands Inc
# 394         ZBH            1              Zimmer Biomet Holdings
# 395          MO            1                    Altria Group Inc
# 396       GOOGL            1                Alphabet Inc Class A
# 397        ALGN            1                                 NaN
# 398        MNST            1                    Monster Beverage
# 399         TAP            1        Molson Coors Brewing Company
# 400         HIG            1          Hartford Financial Svc.Gp.
# 401          HP            1                   Helmerich & Payne
# 402        INCY            1                                 NaN
# 403          ES            1                   Eversource Energy
# 404          WM            1               Waste Management Inc.
# 405         NOV            1         National Oilwell Varco Inc.
# 406        APTV            1                                 NaN
# 407         ADM            1           Archer-Daniels-Midland Co
# 408         STZ            1                Constellation Brands
# 409        ADSK            1                        Autodesk Inc
# 410         ADP            1           Automatic Data Processing
# 411        BHGE            1                                 NaN
# 412        SYMC            1                      Symantec Corp.
# 413        XRAY            1                     Dentsply Sirona
# 414         FOX            1    Twenty-First Century Fox Class B
# 415          PM            1         Philip Morris International
# 416        INFO            1                                 NaN
# 417        DWDP            1                                 NaN
#
#                 GICS Sector                    GICS Sub Industry  \
# 0                Financials       Diversified Financial Services
# 1                Financials     Asset Management & Custody Banks
# 2                Financials                                Banks
# 3                Financials       Investment Banking & Brokerage
# 4                Financials       Investment Banking & Brokerage
# 5                Financials     Asset Management & Custody Banks
# 6                       NaN                                  NaN
# 7                    Energy                 Integrated Oil & Gas
# 8                    Energy   Oil & Gas Exploration & Production
# 9                Financials     Asset Management & Custody Banks
# 10                Utilities                   Electric Utilities
# 11               Financials     Asset Management & Custody Banks
# 12              Industrials              Air Freight & Logistics
# 13                Utilities                       MultiUtilities
# 14              Health Care                  Managed Health Care
# 15                   Energy   Oil & Gas Exploration & Production
# 16   Consumer Discretionary                     Casinos & Gaming
# 17               Financials       Diversified Financial Services
# 18               Financials        Property & Casualty Insurance
# 19              Industrials                            Railroads
# 20               Financials        Property & Casualty Insurance
# 21              Industrials                            Railroads
# 22               Financials     Asset Management & Custody Banks
# 23              Health Care                  Managed Health Care
# 24                Materials                                 Gold
# 25                Utilities                       MultiUtilities
# 26                Utilities                   Electric Utilities
# 27   Consumer Discretionary   Internet & Direct Marketing Retail
# 28               Financials       Diversified Financial Services
# 29              Health Care                  Managed Health Care
# ..                      ...                                  ...
# 388             Real Estate                                REITs
# 389  Consumer Discretionary  Apparel, Accessories & Luxury Goods
# 390             Industrials     Trading Companies & Distributors
# 391             Real Estate                                REITs
# 392        Consumer Staples               Packaged Foods & Meats
# 393  Consumer Discretionary  Apparel, Accessories & Luxury Goods
# 394             Health Care                Health Care Equipment
# 395        Consumer Staples                              Tobacco
# 396  Information Technology         Internet Software & Services
# 397                     NaN                                  NaN
# 398        Consumer Staples                          Soft Drinks
# 399        Consumer Staples                              Brewers
# 400              Financials        Property & Casualty Insurance
# 401                  Energy                   Oil & Gas Drilling
# 402                     NaN                                  NaN
# 403               Utilities                       MultiUtilities
# 404             Industrials               Environmental Services
# 405                  Energy       Oil & Gas Equipment & Services
# 406                     NaN                                  NaN
# 407        Consumer Staples                Agricultural Products
# 408        Consumer Staples                Distillers & Vintners
# 409  Information Technology                 Application Software
# 410  Information Technology         Internet Software & Services
# 411                     NaN                                  NaN
# 412  Information Technology                 Application Software
# 413             Health Care                 Health Care Supplies
# 414  Consumer Discretionary                           Publishing
# 415        Consumer Staples                              Tobacco
# 416                     NaN                                  NaN
# 417                     NaN                                  NaN
#
#               firm
# 0    DEUTSCHE BANK
# 1    DEUTSCHE BANK
# 2    DEUTSCHE BANK
# 3    DEUTSCHE BANK
# 4    DEUTSCHE BANK
# 5    DEUTSCHE BANK
# 6    DEUTSCHE BANK
# 7    DEUTSCHE BANK
# 8    DEUTSCHE BANK
# 9    DEUTSCHE BANK
# 10   DEUTSCHE BANK
# 11   DEUTSCHE BANK
# 12   DEUTSCHE BANK
# 13   DEUTSCHE BANK
# 14   DEUTSCHE BANK
# 15   DEUTSCHE BANK
# 16   DEUTSCHE BANK
# 17   DEUTSCHE BANK
# 18   DEUTSCHE BANK
# 19   DEUTSCHE BANK
# 20   DEUTSCHE BANK
# 21   DEUTSCHE BANK
# 22   DEUTSCHE BANK
# 23   DEUTSCHE BANK
# 24   DEUTSCHE BANK
# 25   DEUTSCHE BANK
# 26   DEUTSCHE BANK
# 27   DEUTSCHE BANK
# 28   DEUTSCHE BANK
# 29   DEUTSCHE BANK
# ..             ...
# 388  DEUTSCHE BANK
# 389  DEUTSCHE BANK
# 390  DEUTSCHE BANK
# 391  DEUTSCHE BANK
# 392  DEUTSCHE BANK
# 393  DEUTSCHE BANK
# 394  DEUTSCHE BANK
# 395  DEUTSCHE BANK
# 396  DEUTSCHE BANK
# 397  DEUTSCHE BANK
# 398  DEUTSCHE BANK
# 399  DEUTSCHE BANK
# 400  DEUTSCHE BANK
# 401  DEUTSCHE BANK
# 402  DEUTSCHE BANK
# 403  DEUTSCHE BANK
# 404  DEUTSCHE BANK
# 405  DEUTSCHE BANK
# 406  DEUTSCHE BANK
# 407  DEUTSCHE BANK
# 408  DEUTSCHE BANK
# 409  DEUTSCHE BANK
# 410  DEUTSCHE BANK
# 411  DEUTSCHE BANK
# 412  DEUTSCHE BANK
# 413  DEUTSCHE BANK
# 414  DEUTSCHE BANK
# 415  DEUTSCHE BANK
# 416  DEUTSCHE BANK
# 417  DEUTSCHE BANK
#
# [418 rows x 6 columns]

# %% [markdown]
# ### Basic Mean data for percentage difference after Upgrade or Downgrade
#
# * chose only firms that have more than 25 instances of each action
# * n = number of instances
# * M as in "dayAfterM" = Mean of price change percentages n days after when the toGrade = the specific action
# * sorted by mean_of_buy_percentages (ascending) if the action is either sell or underperform
# * sorted by mean_of_buy_percentages (decending) if the action is either buy, strong buy, or hold

# %%
buy_stats = stock_analyst_statsdf.loc[stock_analyst_statsdf['toGrade'] == 'Buy'].sort_values('n',ascending = False)
buy_over_25_instances = buy_stats.loc[buy_stats['n'].values>25]
buy_over_25_instances['mean_of_buy_percentages'] = (buy_over_25_instances['dayAfterM']+buy_over_25_instances['days30M']+buy_over_25_instances['days60M']+buy_over_25_instances['days90M'])/4.0
buy_over_25_instances.sort_values('mean_of_buy_percentages',ascending=False)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#
# 0    1.541171    39.0                 1.136230
# 0    3.066179   225.0                 1.135243
# 1    1.979850    42.0                 1.115860
# 1    2.181392    34.0                 1.013596
# 1    1.707815    83.0                 1.008926
# 2    2.681322    84.0                 0.887216
# 0    1.300112   159.0                 0.871017
# 0    1.674225    85.0                 0.728082
# 0    2.796427   144.0                 0.658135
# 0    1.013570    61.0                 0.535265
# 0    0.668577    71.0                 0.425352
# 0    1.743385    45.0                 0.278910
# 1    0.301772    84.0                -0.961771
# 0   -1.131658    49.0                -0.987035
#
# [66 rows x 8 columns]

# %%
sell_stats = stock_analyst_statsdf.loc[stock_analyst_statsdf['toGrade'] == 'Sell'].sort_values('n',ascending = False)
sell_over_25_instances = sell_stats.loc[sell_stats['n'].values>15]
sell_over_25_instances['mean_of_sell_percentages'] = (sell_over_25_instances['dayAfterM']+sell_over_25_instances['days30M']+sell_over_25_instances['days60M']+sell_over_25_instances['days90M'])/4.0
sell_over_25_instances.sort_values('mean_of_sell_percentages',ascending=True)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   toGrade               firm  dayAfterM   days30M   days60M   days90M      n  \
# 3    Sell      DEUTSCHE BANK  -0.213118 -2.256385 -0.334895 -0.503526   68.0
# 2    Sell       PIPERJAFFRAY   0.005738  0.105913  0.419245  2.328252   19.0
# 2    Sell                UBS  -0.210797  0.320556  1.669751  1.738582  116.0
# 2    Sell          BERENBERG   0.331062 -0.500121  1.851155  3.102829   19.0
# 2    Sell    STIFEL NICOLAUS   0.416373  1.256062  1.811356  1.544759   23.0
# 2    Sell          CITIGROUP  -0.056793  0.333578  2.315602  3.873174  183.0
# 2    Sell             NOMURA  -0.304496 -0.075284  2.977931  4.573421   36.0
# 2    Sell  ATLANTIC EQUITIES  -0.076915  2.189116  3.214430  2.888401   30.0
# 0    Sell      GOLDMAN SACHS   0.276601  1.530660  1.884630  4.587736  209.0
# 1    Sell          JP MORGAN  -0.084841  1.957218  3.224032  3.887826  173.0
# 0    Sell   SOCIETE GENERALE  -0.816699  2.290198  4.368477  5.016262   30.0
# 1    Sell           BARCLAYS   0.098805  1.766985  4.006238  5.189930  266.0
# 1    Sell     MORGAN STANLEY  -0.041448  1.503960  4.270347  5.550296  227.0
# 2    Sell  CANACCORD GENUITY   0.293623  0.741947  4.766875  6.141046   16.0
#
#    mean_of_sell_percentages
# 3                 -0.826981
# 2                  0.714787
# 2                  0.879523
# 2                  1.196231
# 2                  1.257137
# 2                  1.616390
# 2                  1.792893
# 2                  2.053758
# 0                  2.069907
# 1                  2.246059
# 0                  2.714559
# 1                  2.765490
# 1                  2.820789
# 2                  2.985873

# %%
hold_stats = stock_analyst_statsdf.loc[stock_analyst_statsdf['toGrade'] == 'Hold'].sort_values('n',ascending = False)
hold_over_25_instances = hold_stats.loc[hold_stats['n'].values>25]
hold_over_25_instances['mean_of_hold_percentages'] = (hold_over_25_instances['dayAfterM']+hold_over_25_instances['days30M']+hold_over_25_instances['days60M']+hold_over_25_instances['days90M'])/4.0
hold_over_25_instances.sort_values('mean_of_hold_percentages',ascending=False)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#
# 0   2.400257   215.0                  1.266820
# 1   1.847975    37.0                  1.160629
# 0   2.500644    92.0                  1.051650
# 1   2.628158   249.0                  0.991181
# 0   2.805440   202.0                  0.968354
# 1   1.398279    88.0                  0.810078
# 1   2.143091   151.0                  0.799148
# 1   1.945534   254.0                  0.757050
# 1   1.479485    67.0                  0.595989
# 0   1.351387    42.0                  0.573077
# 1  -0.766592    33.0                  0.526219
# 1   0.866310    89.0                  0.520819
# 2   0.360585   107.0                  0.028673
# 2   0.012217   159.0                 -0.036250
# 1   0.016899    27.0                 -0.280594
# 0   0.020554    32.0                 -0.300347
# 1  -1.311637    59.0                 -0.970126
# 0  -0.012678    31.0                 -1.101746
#
# [75 rows x 8 columns]

# %%
underperform_stats = stock_analyst_statsdf.loc[stock_analyst_statsdf['toGrade'] == 'Underperform'].sort_values('n',ascending = True)
underperform_over_25_instances = underperform_stats.loc[underperform_stats['n'].values>25]
underperform_over_25_instances['mean_of_underperform_percentages'] = (underperform_over_25_instances['dayAfterM']+underperform_over_25_instances['days30M']+underperform_over_25_instances['days60M']+underperform_over_25_instances['days90M'])/4.0
underperform_over_25_instances.sort_values('mean_of_underperform_percentages',ascending=True)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         toGrade             firm  dayAfterM   days30M   days60M   days90M  \
# 2  Underperform    RAYMOND JAMES  -0.526033 -2.957904  1.164526  1.302877
# 4  Underperform        JEFFERIES  -0.537955  0.566294  0.458757 -0.144211
# 2  Underperform             CLSA  -0.150991  1.165412  2.027547  2.989635
# 2  Underperform      BMO CAPITAL  -0.202850  0.418322  2.306916  4.506455
# 2  Underperform        MACQUARIE  -0.497382  0.303399  1.749107  5.527210
# 2  Underperform    CREDIT SUISSE  -0.439227  1.321531  3.540441  5.041599
# 2  Underperform  BANK OF AMERICA  -0.010429  2.564335  4.514505  6.434456
# 0  Underperform      RBC CAPITAL  -0.217930  3.005958  4.617572  7.821866
# 2  Underperform        BERNSTEIN   0.552486  3.801931  5.377639  7.899127
#
#        n  mean_of_underperform_percentages
# 2   31.0                         -0.254134
# 4   85.0                          0.085721
# 2   66.0                          1.507901
# 2   42.0                          1.757211
# 2   56.0                          1.770584
# 2  144.0                          2.366086
# 2  175.0                          3.375717
# 0   32.0                          3.806866
# 2   35.0                          4.407796

# %%
strong_buy_stats = stock_analyst_statsdf.loc[stock_analyst_statsdf['toGrade'] == 'Strong_buy'].sort_values('n',ascending = False)
strong_buy_over_25_instances = strong_buy_stats.loc[strong_buy_stats['n'].values>25]
strong_buy_over_25_instances['mean_of_strong_buy_percentages'] = (strong_buy_over_25_instances['dayAfterM']+strong_buy_over_25_instances['days30M']+strong_buy_over_25_instances['days60M']+strong_buy_over_25_instances['days90M'])/4.0
strong_buy_over_25_instances.sort_values('mean_of_strong_buy_percentages',ascending=False)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#